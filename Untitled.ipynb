# %%
# !pip install langchain-chroma langchain langchain_community langchainhub
# !pip install --upgrade --quiet gpt4all
# !pip install ollama pandas PyMuPDF
import pandas as pd
import fitz  # PyMuPDF
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import GPT4AllEmbeddings
from langchain_community.llms import Ollama
from langchain.chains import RetrievalQA
from langchain_core.prompts import ChatPromptTemplate
########################################
# 1. LOAD THE CSV OF EXISTING SUMMARIES
########################################
file_path = "C:/Users/Abhilash/OneDrive/Desktop/Mini Project/ReportSummary.csv"
df = pd.read_csv(file_path, encoding='unicode_escape')
df = df[df['Summary'].notna()]

########################################
# 2. CONVERT TO DOCUMENTS
########################################
documents = []
for idx, row in df.iterrows():
    combined_text = (
        f"Report:\n{row['Report']}\n\n"
        f"Existing Summary:\n{row['Summary']}"
    )
    doc = Document(page_content=combined_text, metadata={"row_index": idx})
    documents.append(doc)

########################################
# 3. SPLIT DOCUMENTS
########################################
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
docs_for_vectorstore = text_splitter.split_documents(documents)
# !ollama pull phi3
persist_directory = "./medical_summaries_dB"
vectorstore = Chroma.from_documents(
    docs_for_vectorstore,
    embedding=GPT4AllEmbeddings(),
    persist_directory=persist_directory
)
vectorstore.persist()

########################################
# 5. DEFINE THE CUSTOM PROMPT
########################################
summary_prompt = ChatPromptTemplate.from_template(
"""
You are a helpful assistant that generates easy-to-understand medical summaries
for a layperson, given a new medical report. You may use the provided context 
which consists of existing summaries if it helps and limit word count to 50% of original words.
Context (existing summaries):
{context}

New Medical Report:
{question}

Please provide a clear, concise summary that highlights the key medical details
in a way that a non-technical person would understand.
"""
)

########################################
# 6. RETRIEVAL QA CHAIN
########################################
llm = Ollama(model="phi3")

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectorstore.as_retriever(),
    chain_type="stuff",
    chain_type_kwargs={"prompt": summary_prompt}
)
import re
import fitz  # PyMuPDF

# --------- Function to extract Patient Name (if available) ---------
def extract_patient_name(text):
    # Common pattern: "Patient Name: John Doe" or "Name: John Doe"
    match = re.search(r'(?i)(Patient\s+Name|Name)\s*[:\-]\s*([A-Z][a-z]+\s+[A-Z][a-z]+)', text)
    if match:
        return match.group(2).strip()
    return "Patient name not found."

# --------- Function to extract Findings section ---------
def extract_findings_section(text):
    match = re.search(r'(?i)findings\s*[:\-]*\s*(.+?)(?=\n[A-Z][A-Za-z ]{2,}[:\-])', text, re.DOTALL)
    if match:
        return match.group(1).strip()
    return "Findings section not found in the report."

# --------- Function to clean non-useful gibberish ---------
def clean_findings_text(text):
    lines = text.splitlines()
    cleaned_lines = []
    for line in lines:
        if len(line.strip()) > 3 and not re.search(r'[^a-zA-Z0-9\s.,:;()%\-]', line):
            if not line.strip().isupper():
                cleaned_lines.append(line)
    return '\n'.join(cleaned_lines).strip()

# --------- User Input: PDF path ---------
pdf_path = input("Enter path to the PDF report: ").strip('"')

# --------- Extract full text from PDF ---------
doc = fitz.open(pdf_path)
full_text = ""
for page in doc:
    full_text += page.get_text()

# --------- Extract Patient Name ---------
patient_name = extract_patient_name(full_text)

# --------- Extract and Clean Findings Section ---------
raw_findings_text = extract_findings_section(full_text)
findings_text = clean_findings_text(raw_findings_text)

# --------- Run Summarization ---------
result = qa_chain.run(findings_text)

# --------- Display Result ---------
print("\n----- Summary for Patient -----")
print(f"Patient Name: {patient_name}")
print("\n----- Summarized Findings -----")
print(result)
# Out:
# Requirement already satisfied: langchain-chroma in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (0.2.2)
# Requirement already satisfied: langchain in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (0.3.23)
# Requirement already satisfied: langchain_community in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (0.3.21)
# Requirement already satisfied: langchainhub in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (0.1.21)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain-chroma) (0.3.51)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain-chroma) (0.6.3)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain-chroma) (1.26.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.0.40)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.3.30)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.11.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: requests<3,>=2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain_community) (3.11.16)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain_community) (2.8.1)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchainhub) (2.32.0.20250328)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchainhub) (24.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.19.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.10.16)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.71.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.32.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (32.0.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.3.0)
# Requirement already satisfied: importlib-resources in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (6.5.2)
# Collecting httpx>=0.27.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.21.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.34.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.32.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.67.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.21.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.53b0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.15.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (7.7.0)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.7.6)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.32.0)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.115.12)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.1.0)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.24.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.13.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (14.0.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.48.9)
# Requirement already satisfied: pyproject_hooks in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (8.6.1)
# Requirement already satisfied: colorama in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from fastapi>=0.95.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.46.1)
# Requirement already satisfied: certifi in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2025.1.31)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.8-py3-none-any.whl (78 kB)
# Requirement already satisfied: anyio in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.9.0)
# Requirement already satisfied: idna in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.10)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: zipp>=3.20 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.21.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.38.0)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.4.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.8.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.9)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: requests-oauthlib in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.0.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.17.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (4.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain-chroma) (3.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: flatbuffers in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (5.29.4)
# Requirement already satisfied: coloredlogs in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: sympy in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.18)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.17.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.69.2)
# Requirement already satisfied: opentelemetry-proto==1.32.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.32.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.32.0)
# Requirement already satisfied: opentelemetry-util-http==0.53b0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.53b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.53b0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.53b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.53b0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.53b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.53b0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-instrumentation-asgi==0.53b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.9.0)
# Requirement already satisfied: monotonic>=1.5 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.6)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.1.2)
# Requirement already satisfied: greenlet>=1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.2.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.30.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (2025.3.2)
# Requirement already satisfied: filelock in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.18.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (15.0.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (0.6.4)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.7.0,>=0.4.0->langchain-chroma) (1.3.0)
# Installing collected packages: h11, httpcore, httpx
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
# Successfully installed h11-0.14.0 httpcore-1.0.8 httpx-0.28.1
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\Abhilash\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\Abhilash\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: ollama in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (0.4.7)
# Requirement already satisfied: pandas in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: PyMuPDF in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (1.25.5)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from ollama) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: httpcore==1.* in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.8)
# Requirement already satisfied: certifi in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2025.1.31)
# Requirement already satisfied: anyio in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.9.0)
# Requirement already satisfied: idna in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.13.2)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhilash\appdata\local\programs\python\python310\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\Abhilash\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 get_ipython().system('pip install ollama pandas PyMuPDF')
#       4 import pandas as pd
# ----> 5 import fitz  # PyMuPDF
#       6 from langchain.schema import Document
#       7 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# ModuleNotFoundError: No module named 'frontend'
